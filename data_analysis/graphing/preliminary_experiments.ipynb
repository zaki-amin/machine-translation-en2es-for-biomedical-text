# %%
import pandas as pd
from matplotlib import pyplot as plt


def plot_grouped_bar_chart(df: pd.DataFrame):
    ax = df.plot(x='Model', kind='bar', stacked=False, title='Metrics for different models')
    ax.set_xlabel('Model', fontsize=12)
    ax.set_ylabel('Scores', fontsize=12)
    ax.set_ylim(0, 100) 
    ax.set_yticks(range(0, 101, 10))
    ax.tick_params(axis='x', rotation=45)
    plt.tight_layout()
    plt.show()

# %%
data = pd.DataFrame([['Helsinki-NLP', 42.8, 49.5, 90.9],
                     ['Meta NLLB 600M', 39.0, 44.9, 90.1],
                     ['Meta NLLB 3.3B', 40.2, 46.2, 90.3],
                     ['Google Madlad', 44.8, 51.2, 91.2]],
                    columns=['Model', 'SacreBLEU', '`WER`', 'Semantic similarity'])

plot_grouped_bar_chart(data)
