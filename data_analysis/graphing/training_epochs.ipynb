# %% [markdown]
# # Plotting curves of validation loss against epochs

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
def plot_training_evolution_curve(data: list[tuple[int, float]]):
    """Plot the curve of validation loss against epochs.
    Args:
        data: a list of tuples, where each tuple contains the epoch number and the validation loss."""
    epochs = [epoch for epoch, _ in data]
    loss = [loss for _, loss in data]
    plt.plot(epochs, loss)
    
    plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
    plt.xlabel('Epoch')
    plt.ylabel('Validation loss')
    plt.title('Validation loss over epochs')
    plt.show()

# %%
data = [(1, 0.55), (2, 0.62), (3, 0.64)]
plot_training_evolution_curve(data)
